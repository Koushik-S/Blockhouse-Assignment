# %% [markdown]
# #Transformer Model

# %% [markdown]
# #### Load the dataset and preprocess the dataframe in the required format.

# %% [markdown]
# Technical indicators created for the environment include:
#
# - RSI
# - MACD
# - Stoch_k
# - OBV
# - Upper_BB
# - ATR_1
# - ATR_2
# - ATR_5
# - ATR_10
# - ATR_20

# %%
import pandas as pd
import numpy as np
import talib as ta

class TechnicalIndicators:
    def __init__(self, data):
        self.data = data

    def add_momentum_indicators(self):
        self.data['RSI'] = ta.RSI(self.data['Close'], timeperiod=14)
        self.data['MACD'], self.data['MACD_signal'], self.data['MACD_hist'] = ta.MACD(self.data['Close'], fastperiod=12, slowperiod=26, signalperiod=9)
        self.data['Stoch_k'], self.data['Stoch_d'] = ta.STOCH(self.data['High'], self.data['Low'], self.data['Close'],
                                                              fastk_period=14, slowk_period=3, slowd_period=3)

    def add_volume_indicators(self):
        self.data['OBV'] = ta.OBV(self.data['Close'], self.data['Volume'])

    def add_volatility_indicators(self):
        self.data['Upper_BB'], self.data['Middle_BB'], self.data['Lower_BB'] = ta.BBANDS(self.data['Close'], timeperiod=20)
        self.data['ATR_1'] = ta.ATR(self.data['High'], self.data['Low'], self.data['Close'], timeperiod=1)
        self.data['ATR_2'] = ta.ATR(self.data['High'], self.data['Low'], self.data['Close'], timeperiod=2)
        self.data['ATR_5'] = ta.ATR(self.data['High'], self.data['Low'], self.data['Close'], timeperiod=5)
        self.data['ATR_10'] = ta.ATR(self.data['High'], self.data['Low'], self.data['Close'], timeperiod=10)
        self.data['ATR_20'] = ta.ATR(self.data['High'], self.data['Low'], self.data['Close'], timeperiod=20)

    def add_trend_indicators(self):
        self.data['ADX'] = ta.ADX(self.data['High'], self.data['Low'], self.data['Close'], timeperiod=14)
        self.data['+DI'] = ta.PLUS_DI(self.data['High'], self.data['Low'], self.data['Close'], timeperiod=14)
        self.data['-DI'] = ta.MINUS_DI(self.data['High'], self.data['Low'], self.data['Close'], timeperiod=14)
        self.data['CCI'] = ta.CCI(self.data['High'], self.data['Low'], self.data['Close'], timeperiod=5)

    def add_other_indicators(self):
        self.data['DLR'] = np.log(self.data['Close'] / self.data['Close'].shift(1))
        self.data['TWAP'] = self.data['Close'].expanding().mean()
        self.data['VWAP'] = (self.data['Volume'] * (self.data['High'] + self.data['Low']) / 2).cumsum() / self.data['Volume'].cumsum()

    def add_all_indicators(self):
        self.add_momentum_indicators()
        self.add_volume_indicators()
        self.add_volatility_indicators()
        self.add_trend_indicators()
        self.add_other_indicators()
        self.create_labels()
        return self.data
    def create_labels(self):
        self.data['Label'] = 0  # Default to Hold

        # Side-based labeling
        self.data.loc[self.data['side'] == 'B', 'Label'] = 1  # Buy
        self.data.loc[self.data['side'] == 'A', 'Label'] = 2  #sell

# %%
data = pd.read_csv('/content/xnas-itch-20230703.tbbo.csv')

# Preprocessing to create necessary columns
data['price']=data['price']/1e9
data['bid_px_00']=data['bid_px_00']/1e9
data['ask_px_00']=data['ask_px_00']/1e9

data['Close'] = data['price']
data['Volume'] = data['size']
data['High'] = data[['bid_px_00', 'ask_px_00']].max(axis=1)
data['Low'] = data[['bid_px_00', 'ask_px_00']].min(axis=1)
data['Open'] = data['Close'].shift(1).fillna(data['Close'])


ti = TechnicalIndicators(data)
df_with_indicators = ti.add_all_indicators()
market_features_df = df_with_indicators[35:]

# %% [markdown]
# Checking the dataset:

# %%
list(market_features_df['side']).count('N')
# Out:
# 7896

# %%
# Show all columns in pandas
pd.set_option('display.max_columns', None)

market_features_df.head(35)

# %%
df_with_indicators.info()

# %%
market_features_df.to_csv("market_features_df_new.csv")

# %% [markdown]
# ### Transformer Model

# %%
import pandas as pd
import numpy as np

# %%
market_features_df=pd.read_csv("/content/market_features_df_new.csv")

# %%
market_features_df.columns
# Out:
# Index(['Unnamed: 0', 'ts_recv', 'ts_event', 'rtype', 'publisher_id',
#        'instrument_id', 'action', 'side', 'depth', 'price', 'size', 'flags',
#        'ts_in_delta', 'sequence', 'bid_px_00', 'ask_px_00', 'bid_sz_00',
#        'ask_sz_00', 'bid_ct_00', 'ask_ct_00', 'symbol', 'Close', 'Volume',
#        'High', 'Low', 'Open', 'RSI', 'MACD', 'MACD_signal', 'MACD_hist',
#        'Stoch_k', 'Stoch_d', 'OBV', 'Upper_BB', 'Middle_BB', 'Lower_BB',
#        'ATR_1', 'ATR_2', 'ATR_5', 'ATR_10', 'ATR_20', 'ADX', '+DI', '-DI',
#        'CCI', 'DLR', 'TWAP', 'VWAP', 'Label'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
from torch.utils.data import Dataset

class SequenceDataset(Dataset):
    def __init__(self, data, seq_length, state_columns):
        self.data = data
        self.seq_length = seq_length
        self.state_columns = state_columns

    def __len__(self):
        return len(self.data) - self.seq_length

    def __getitem__(self, idx):
        seq = self.data[self.state_columns].iloc[idx:idx+self.seq_length].values
        label = self.data['Label'].iloc[idx+self.seq_length]
        return torch.tensor(seq, dtype=torch.float32), torch.tensor(label, dtype=torch.long)

# Parameters
seq_length = 50
state_columns = ['Close', 'Volume', 'RSI', 'MACD', 'MACD_signal', 'Stoch_k', 'Stoch_d',
                 'OBV', 'Upper_BB', 'Middle_BB', 'Lower_BB', 'ATR_1', 'ADX', '+DI', '-DI', 'CCI']
market_features_df[state_columns] = scaler.fit_transform(market_features_df[state_columns])
# Create the dataset
dataset = SequenceDataset(market_features_df, seq_length, state_columns)

# Create DataLoader
batch_size = 64
data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class TransformerModel(nn.Module):
    def __init__(self, input_dim, model_dim, num_heads, num_layers, output_dim):
        super(TransformerModel, self).__init__()
        self.embedding = nn.Linear(input_dim, model_dim)
        encoder_layer = nn.TransformerEncoderLayer(d_model=model_dim, nhead=num_heads)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        self.fc = nn.Linear(model_dim, output_dim)

    def forward(self, src):
        src = self.embedding(src)
        src = src.permute(1, 0, 2)  # Transformer expects (seq_len, batch_size, feature_dim)
        transformer_output = self.transformer_encoder(src)
        output = self.fc(transformer_output.mean(dim=0))
        return output

# Model parameters
input_dim = len(state_columns)
model_dim = 64
num_heads = 4
num_layers = 2
output_dim = 3  # Buy, Sell, Hold

model = TransformerModel(input_dim, model_dim, num_heads, num_layers, output_dim).to(device)
print(device)
# Out:
# cuda
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %%
# Split the data into train and test sets (80-20 split)
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

# Create DataLoader for train and test sets
batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Training parameters
learning_rate = 0.0005  #  Smaller learning rate
epochs = 15

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Training loop with gradient clipping
for epoch in range(epochs):
    model.train()
    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)  # Gradient clipping
        optimizer.step()
    print(f'Epoch [{epoch+1}/{epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [1/15], Loss: 0.8451
# Epoch [2/15], Loss: 0.9249
# Epoch [3/15], Loss: 0.7626
# Epoch [4/15], Loss: 0.7905
# Epoch [5/15], Loss: 0.7988
# Epoch [6/15], Loss: 0.8176
# Epoch [7/15], Loss: 0.7826
# Epoch [8/15], Loss: 0.7004
# Epoch [9/15], Loss: 0.7189
# Epoch [10/15], Loss: 0.8319
# Epoch [11/15], Loss: 0.6561
# Epoch [12/15], Loss: 0.8328
# Epoch [13/15], Loss: 0.6637
# Epoch [14/15], Loss: 0.6406
# Epoch [15/15], Loss: 0.7546

# %%
model_path = 'transformer_model_v1.pth'
torch.save(model.state_dict(), model_path)
print(f'Model saved to {model_path}')
# Out:
# Model saved to transformer_model_v1.pth

# %%
# Evaluate the model
model.eval()
correct = 0
total = 0
running_loss = 0.0
with torch.no_grad():
    for inputs, targets in test_loader:
        inputs, targets = inputs.to(device), targets.to(device)
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += targets.size(0)
        correct += (predicted == targets).sum().item()

test_loss = running_loss / len(test_loader)
test_accuracy = correct / total * 100
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%')
# Out:
# Test Loss: 0.7897, Test Accuracy: 66.78%

# %% [markdown]
# ### TRADING BLOTTER:

# %% [markdown]
# #### Preprocess the data for the trading blotter:

# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

INITIAL_CASH = 10_000_000  # $10 million

def preprocess_data(df):
    df['liquidity'] = df['bid_sz_00'] * df['bid_px_00'] + df['ask_sz_00'] * df['ask_px_00']
    return df

def calculate_rsi(data, window=14):
    delta = data.diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    rs = gain / loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

def calculate_vol_and_liquidity(price_df, volume_df, window_size):
    # Calculate rolling statistics
    rolling_mean_vol = price_df.pct_change().rolling(window=window_size).mean()
    rolling_std_vol = price_df.pct_change().rolling(window=window_size).std()
    rolling_mean_liq = volume_df.rolling(window=window_size).mean()
    rolling_std_liq = volume_df.rolling(window=window_size).std()

    return rolling_mean_vol, rolling_std_vol, rolling_mean_liq, rolling_std_liq

def get_percentile(current_value, mean, std):
    if std > 0:
        z_score = (current_value - mean) / std
        percentile = norm.cdf(z_score)
    else:
        percentile = 0.5  # No variation
    return percentile

def get_trade_price(base_price, current_vol, current_liq, mean_vol, std_vol, mean_liq, std_liq, trade_direction):
    vol_percentile = get_percentile(current_vol, mean_vol, std_vol)
    liq_percentile = get_percentile(current_liq, mean_liq, std_liq)

    # Define price adjustment scenarios based on market conditions
    if vol_percentile >= 0.9 and liq_percentile < 0.1:
        price_adjustment_percent = np.random.uniform(-0.25, -0.15)
    elif vol_percentile <= 0.1 and liq_percentile < 0.1:
        price_adjustment_percent = np.random.uniform(-0.10, -0.05)
    elif vol_percentile >= 0.9 and liq_percentile >= 0.9:
        price_adjustment_percent = np.random.uniform(-0.05, +0.10)
    else:
        price_adjustment_percent = np.random.uniform(-0.05, +0.05)  # Default for normal conditions

    # Adjust price based on trade direction
    if trade_direction == 'BUY':
        adjusted_price = base_price * (1 - price_adjustment_percent)
    else:  # SELL
        adjusted_price = base_price * (1 + price_adjustment_percent)

    return adjusted_price

# %% [markdown]
# #### Create trading environment for the blotter

# %%
class TradingEnvironmentwithBlotter:
    def __init__(self, data, daily_trading_limit, window_size):
        self.data = preprocess_data(data)
        self.daily_trading_limit = daily_trading_limit
        self.window_size = window_size
        self.state_columns = ['price', 'liquidity', 'RSI', 'MACD', 'MACD_signal', 'MACD_hist', 'Stoch_k', 'Stoch_d',
                              'OBV', 'Upper_BB', 'Middle_BB', 'Lower_BB', 'ATR_1', 'ADX', '+DI', '-DI', 'CCI']
        self.reset()

    def reset(self):
        self.current_step = 0
        self.balance = INITIAL_CASH
        self.shares_held = 0
        self.total_shares_traded = 0
        self.cumulative_reward = 0
        self.trades = []
        self.portfolio = {'cash': self.balance, 'holdings': {ticker: 0 for ticker in self.data['symbol'].unique()}}
        self.data['RSI'] = calculate_rsi(self.data['price'])
        self.data['pct_change'] = self.data['price'].pct_change()
        self.data['rolling_mean_vol'], self.data['rolling_std_vol'], self.data['rolling_mean_liq'], self.data['rolling_std_liq'] = calculate_vol_and_liquidity(self.data['price'], self.data['liquidity'], self.window_size)

    def step(self):
        row = self.data.iloc[self.current_step]
        current_price = row['price']
        current_time = pd.to_datetime(row['ts_event'])
        current_rsi = row['RSI']
        current_vol = row['pct_change']
        current_liq = row['liquidity']
        mean_vol = row['rolling_mean_vol']
        std_vol = row['rolling_std_vol']
        mean_liq = row['rolling_mean_liq']
        std_liq = row['rolling_std_liq']

        if current_rsi < 30:  # Entry signal based on RSI
            trade_direction = 'BUY'
            trade_price = get_trade_price(current_price, current_vol, current_liq, mean_vol, std_vol, mean_liq, std_liq, trade_direction)
            trade_size = (self.portfolio['cash'] * np.random.uniform(0.001, 0.005)) / trade_price
            if self.portfolio['cash'] >= trade_size * trade_price:
                self.portfolio['cash'] -= trade_size * trade_price
                self.portfolio['holdings'][row['symbol']] += trade_size
                trade_status = 'filled'
            else:
                trade_status = 'cancelled'
        elif current_rsi > 70:  # Exit signal based on RSI
            trade_direction = 'SELL'
            if self.portfolio['holdings'][row['symbol']] > 0:
                trade_size = min(self.portfolio['holdings'][row['symbol']], self.portfolio['cash']*np.random.uniform(0.001, 0.005) / current_price)
                trade_price = get_trade_price(current_price, current_vol, current_liq, mean_vol, std_vol, mean_liq, std_liq, trade_direction)
                self.portfolio['cash'] += trade_size * trade_price
                self.portfolio['holdings'][row['symbol']] -= trade_size
                trade_status = 'filled'
            else:
                trade_size = 0
                trade_status = 'cancelled'
        else:
            trade_direction = 'HOLD'
            trade_size = 0
            trade_price = current_price
            trade_status = 'skipped'

        if trade_size > 0:
            expected_price = row['ask_px_00']
            actual_price = row['price']
            transaction_time = row['ts_in_delta']
            transaction_cost = self._calculate_transaction_cost(row['Volume'], 0.3, self.data['Volume'].mean())
            slippage = expected_price - actual_price
            time_penalty = 1000 * transaction_time / 1e9
            reward = - (slippage + time_penalty + transaction_cost)

            self.cumulative_reward += reward
            self.trades.append({
                'step': self.current_step,
                'timestamp': current_time,
                'action': trade_direction,
                'price': trade_price,
                'shares': trade_size,
                'symbol': row['symbol'],
                'reward': reward,
                'transaction_cost': transaction_cost,
                'slippage': slippage,
                'time_penalty': time_penalty
            })



        self.current_step += 1
        if self.current_step >= len(self.data) - 1:
            done=True
            self.current_step = 0

    def _calculate_transaction_cost(self, volume, volatility, daily_volume):
        return volatility * np.sqrt(volume / daily_volume)

    def run(self):
        self.reset()
        for _ in range(len(self.data)):
            self.step()
        return self.cumulative_reward, self.trades

    def render(self):
        print(f'Cumulative reward: {self.cumulative_reward}')
        row = self.data.iloc[self.current_step]
        print(f'Total portfolio value: {self.portfolio["cash"] + self.portfolio["holdings"][row["symbol"]]*row["Close"]}')
        # get trades in a pandas dataframe
        trades_df = pd.DataFrame(self.trades)
        # Save a csv
        trades_df.to_csv('trades_blotter.csv', index=False)
        for trade in self.trades:
            print(f"Step: {trade['step']}, Timestamp: {trade['timestamp']}, Action: {trade['action']}, Price: {trade['price']}, Shares: {trade['shares']}, Symbol: {trade['symbol']}, Reward: {trade['reward']}, Transaction Cost: {trade['transaction_cost']}, Slippage: {trade['slippage']}, Time Penalty: {trade['time_penalty']}")

# %% [markdown]
# #### Run the trading blotter

# %%
# Filter data for the specified ticker
ticker = 'AAPL'  # Specify the ticker you want to trade
ticker_data = market_features_df[market_features_df['symbol'] == ticker]

window_size = 60
daily_trading_limit = 1000
# Create the trading environment
env = TradingEnvironmentwithBlotter(ticker_data, daily_trading_limit=1000, window_size=window_size)  # Daily trading limit of 1000 shares

# Run the environment
cumulative_reward, trades = env.run()

# Render the results
env.render()
# Out:
# <ipython-input-28-14d8af0093b1>:92: RuntimeWarning: invalid value encountered in sqrt
#   return volatility * np.sqrt(volume / daily_volume)
# Streaming output truncated to the last 5000 lines.
# Step: 14939, Timestamp: 2023-07-03 13:48:36.504145419, Action: SELL, Price: 196.94519601243076, Shares: 12.55682788309265, Symbol: AAPL, Reward: -26341919.31232232, Transaction Cost: 26341919.147964317, Slippage: 0.0, Time Penalty: 0.164358
# Step: 14940, Timestamp: 2023-07-03 13:48:36.504172478, Action: SELL, Price: 188.61555077594159, Shares: 17.398692109543468, Symbol: AAPL, Reward: -66125222.233492106, Transaction Cost: 66125222.069031104, Slippage: 0.0, Time Penalty: 0.164461
# Step: 14941, Timestamp: 2023-07-03 13:48:36.504173973, Action: SELL, Price: 192.7548957284633, Shares: 15.901794704702903, Symbol: AAPL, Reward: -2942498.694806076, Transaction Cost: 2942498.5252460763, Slippage: 0.0, Time Penalty: 0.16956
# Step: 14942, Timestamp: 2023-07-03 13:48:36.505096066, Action: SELL, Price: 186.771133338017, Shares: 27.983413008972864, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.16738
# Step: 14943, Timestamp: 2023-07-03 13:48:36.505225479, Action: SELL, Price: 188.36344600791338, Shares: 23.98645694255303, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.165822
# Step: 14953, Timestamp: 2023-07-03 13:48:38.031667929, Action: BUY, Price: 195.48575201881616, Shares: 17.338392875399855, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.165715
# Step: 14954, Timestamp: 2023-07-03 13:48:38.031667929, Action: BUY, Price: 186.56494967969113, Shares: 19.4023594943166, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.165715
# Step: 14956, Timestamp: 2023-07-03 13:48:40.124174771, Action: BUY, Price: 193.47229389864708, Shares: 28.139834151201775, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0049999999999954525, Time Penalty: 0.165243
# Step: 14957, Timestamp: 2023-07-03 13:48:40.124174771, Action: BUY, Price: 183.8194449482903, Shares: 6.224130727479291, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0049999999999954525, Time Penalty: 0.165243
# Step: 14962, Timestamp: 2023-07-03 13:48:40.435762138, Action: SELL, Price: 199.6323274299862, Shares: 11.572468659907472, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.164354
# Step: 14979, Timestamp: 2023-07-03 13:48:42.876286918, Action: BUY, Price: 189.24410959852784, Shares: 13.701099508739269, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.170543
# Step: 14980, Timestamp: 2023-07-03 13:48:42.876286918, Action: BUY, Price: 193.30472763375718, Shares: 7.733783120627045, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.170543
# Step: 14981, Timestamp: 2023-07-03 13:48:42.876286918, Action: BUY, Price: 192.63915007157408, Shares: 21.244012680859907, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.170543
# Step: 14982, Timestamp: 2023-07-03 13:48:42.876286918, Action: BUY, Price: 201.97939110827477, Shares: 14.75500731240205, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.170543
# Step: 14983, Timestamp: 2023-07-03 13:48:42.876286918, Action: BUY, Price: 186.25107407840997, Shares: 27.621528187333464, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.170543
# Step: 14984, Timestamp: 2023-07-03 13:48:42.876286918, Action: BUY, Price: 187.97183406124498, Shares: 15.556945723374733, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.170543
# Step: 14985, Timestamp: 2023-07-03 13:48:43.003788774, Action: BUY, Price: 189.20467453414327, Shares: 26.72185783329957, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.16879
# Step: 14986, Timestamp: 2023-07-03 13:48:43.003788774, Action: BUY, Price: 187.33294559702315, Shares: 11.787606015630963, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.16879
# Step: 14987, Timestamp: 2023-07-03 13:48:43.003788774, Action: BUY, Price: 198.6694772204956, Shares: 20.495543939660937, Symbol: AAPL, Reward: -22260687.898758717, Transaction Cost: 22260687.729968715, Slippage: 0.0, Time Penalty: 0.16879
# Step: 14988, Timestamp: 2023-07-03 13:48:43.003788774, Action: BUY, Price: 193.89278177073695, Shares: 18.12580587658514, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.16879
# Step: 14989, Timestamp: 2023-07-03 13:48:43.003788774, Action: BUY, Price: 201.75235027939664, Shares: 24.221299057313765, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.16879
# Step: 14990, Timestamp: 2023-07-03 13:48:43.084667357, Action: BUY, Price: 187.34814989705635, Shares: 20.200058632050688, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.165153
# Step: 14991, Timestamp: 2023-07-03 13:48:43.301070974, Action: BUY, Price: 201.49972972725317, Shares: 6.216972286025986, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.175935
# Step: 14992, Timestamp: 2023-07-03 13:48:43.301070974, Action: BUY, Price: 185.69323879194368, Shares: 7.154148226263526, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.175935
# Step: 14993, Timestamp: 2023-07-03 13:48:43.301070974, Action: BUY, Price: 187.73101581438416, Shares: 18.355111422813216, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.175935
# Step: 14994, Timestamp: 2023-07-03 13:48:43.301070974, Action: BUY, Price: 200.40479293472208, Shares: 8.720660027610284, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.175935
# Step: 14995, Timestamp: 2023-07-03 13:48:43.301070974, Action: BUY, Price: 185.37318780240133, Shares: 8.618353170003987, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.175935
# Step: 14996, Timestamp: 2023-07-03 13:48:43.301070974, Action: BUY, Price: 196.19646859269548, Shares: 11.03814909722649, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.175935
# Step: 14997, Timestamp: 2023-07-03 13:48:43.301070974, Action: BUY, Price: 202.17446603926194, Shares: 11.130101773528576, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.175935
# Step: 14998, Timestamp: 2023-07-03 13:48:43.301188599, Action: BUY, Price: 190.63406412070958, Shares: 6.07258715680252, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.167424
# Step: 14999, Timestamp: 2023-07-03 13:48:43.301188599, Action: BUY, Price: 184.42815525363153, Shares: 25.64864043811647, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.167424
# Step: 15000, Timestamp: 2023-07-03 13:48:43.311921190, Action: BUY, Price: 189.58032337977463, Shares: 23.610459249263755, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164284
# Step: 15001, Timestamp: 2023-07-03 13:48:43.485247037, Action: BUY, Price: 186.5964552693699, Shares: 8.542432343169198, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.168957
# Step: 15002, Timestamp: 2023-07-03 13:48:43.485247037, Action: BUY, Price: 199.2429015511035, Shares: 17.371508004639423, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.168957
# Step: 15003, Timestamp: 2023-07-03 13:48:43.485247037, Action: BUY, Price: 198.74144997036996, Shares: 22.441269931518843, Symbol: AAPL, Reward: -124565988.31151696, Transaction Cost: 124565988.13255996, Slippage: 0.009999999999990905, Time Penalty: 0.168957
# Step: 15004, Timestamp: 2023-07-03 13:48:43.485247037, Action: BUY, Price: 200.63571005533572, Shares: 20.04730724217887, Symbol: AAPL, Reward: -16707697.278531596, Transaction Cost: 16707697.099574596, Slippage: 0.009999999999990905, Time Penalty: 0.168957
# Step: 15005, Timestamp: 2023-07-03 13:48:43.485247037, Action: BUY, Price: 185.33368612390848, Shares: 27.719653954800684, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.175954
# Step: 15006, Timestamp: 2023-07-03 13:48:43.485247037, Action: BUY, Price: 192.44924047368048, Shares: 25.755737373740175, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.175954
# Step: 15007, Timestamp: 2023-07-03 13:48:43.485247037, Action: BUY, Price: 198.96894572614445, Shares: 13.592118603123218, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.175954
# Step: 15008, Timestamp: 2023-07-03 13:48:43.485247037, Action: BUY, Price: 198.2264536264907, Shares: 24.463768341560165, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.175954
# Step: 15009, Timestamp: 2023-07-03 13:48:43.485247037, Action: BUY, Price: 197.39925715397632, Shares: 22.490793842411865, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.175954
# Step: 15010, Timestamp: 2023-07-03 13:48:43.485247037, Action: BUY, Price: 188.91322809042512, Shares: 20.16841074452822, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.175954
# Step: 15011, Timestamp: 2023-07-03 13:48:43.485247037, Action: BUY, Price: 197.27266128669118, Shares: 8.23072023235627, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.175954
# Step: 15012, Timestamp: 2023-07-03 13:48:43.485276894, Action: BUY, Price: 196.27978518953736, Shares: 11.112643137404566, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.166548
# Step: 15013, Timestamp: 2023-07-03 13:48:43.486294620, Action: BUY, Price: 198.48026723724027, Shares: 9.379350128026534, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.167308
# Step: 15014, Timestamp: 2023-07-03 13:48:43.486294620, Action: BUY, Price: 186.83673708407306, Shares: 16.672472572724132, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.167308
# Step: 15015, Timestamp: 2023-07-03 13:48:43.486294620, Action: BUY, Price: 192.31681850832118, Shares: 8.256846034527232, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.167308
# Step: 15016, Timestamp: 2023-07-03 13:48:43.786932015, Action: BUY, Price: 187.32318186608367, Shares: 27.280496803479764, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.020000000000010232, Time Penalty: 0.166233
# Step: 15017, Timestamp: 2023-07-03 13:48:43.786932015, Action: BUY, Price: 195.60389047329488, Shares: 5.719325655657318, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.020000000000010232, Time Penalty: 0.166233
# Step: 15022, Timestamp: 2023-07-03 13:48:44.527131293, Action: BUY, Price: 196.26575902853568, Shares: 7.7868246672048995, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.169256
# Step: 15023, Timestamp: 2023-07-03 13:48:44.527131293, Action: BUY, Price: 184.25803892030459, Shares: 17.86437930329282, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.169256
# Step: 15024, Timestamp: 2023-07-03 13:48:44.527131293, Action: BUY, Price: 194.26315796282145, Shares: 24.307713779833335, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.169256
# Step: 15025, Timestamp: 2023-07-03 13:48:44.527131293, Action: BUY, Price: 186.03717512466605, Shares: 16.202788516165853, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.169256
# Step: 15026, Timestamp: 2023-07-03 13:48:44.527131293, Action: BUY, Price: 188.4612353724186, Shares: 26.327730644765257, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.169256
# Step: 15041, Timestamp: 2023-07-03 13:48:44.968678570, Action: SELL, Price: 196.86336300524732, Shares: 14.01916995901729, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.166356
# Step: 15042, Timestamp: 2023-07-03 13:48:44.968678570, Action: SELL, Price: 198.22361065298742, Shares: 11.983872210410114, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.166356
# Step: 15043, Timestamp: 2023-07-03 13:48:44.969022939, Action: SELL, Price: 211.15856436484634, Shares: 18.021801623303503, Symbol: AAPL, Reward: -67207185.12934026, Transaction Cost: 67207184.96489327, Slippage: 0.0, Time Penalty: 0.164447
# Step: 15044, Timestamp: 2023-07-03 13:48:44.969094746, Action: SELL, Price: 198.1253936006414, Shares: 18.34563236104428, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.165105
# Step: 15045, Timestamp: 2023-07-03 13:48:44.969211265, Action: SELL, Price: 192.56317909569356, Shares: 15.85442269311951, Symbol: AAPL, Reward: -29260724.886842314, Transaction Cost: 29260724.722363316, Slippage: 0.0, Time Penalty: 0.164479
# Step: 15046, Timestamp: 2023-07-03 13:48:44.969215122, Action: SELL, Price: 199.244757677144, Shares: 25.337894578897426, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164132
# Step: 15047, Timestamp: 2023-07-03 13:48:44.969250218, Action: SELL, Price: 188.30295310404625, Shares: 16.713576900864464, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.165206
# Step: 15048, Timestamp: 2023-07-03 13:48:44.970071496, Action: SELL, Price: 183.7293309644203, Shares: 18.41762747329927, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164487
# Step: 15049, Timestamp: 2023-07-03 13:48:44.970583053, Action: SELL, Price: 191.98371339327232, Shares: 22.945063674953005, Symbol: AAPL, Reward: -66125222.2426621, Transaction Cost: 66125222.069031104, Slippage: 0.0, Time Penalty: 0.173631
# Step: 15050, Timestamp: 2023-07-03 13:48:44.970583053, Action: SELL, Price: 194.85352816128557, Shares: 14.42201694541724, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.173631
# Step: 15051, Timestamp: 2023-07-03 13:48:44.970583053, Action: SELL, Price: 197.97368419645875, Shares: 18.565581439321715, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.173631
# Step: 15052, Timestamp: 2023-07-03 13:48:44.970583053, Action: SELL, Price: 193.2202946615501, Shares: 16.07031380172606, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.173631
# Step: 15053, Timestamp: 2023-07-03 13:48:44.970583053, Action: SELL, Price: 185.15674770833124, Shares: 19.987331143718414, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.173631
# Step: 15054, Timestamp: 2023-07-03 13:48:45.361714327, Action: SELL, Price: 200.71055517126905, Shares: 19.989573446658042, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.164711
# Step: 15055, Timestamp: 2023-07-03 13:48:45.362225403, Action: SELL, Price: 195.69061010533525, Shares: 23.46935749205174, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.164257
# Step: 15056, Timestamp: 2023-07-03 13:48:47.893879816, Action: SELL, Price: 200.64403124582563, Shares: 25.240998284274788, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.168071
# Step: 15062, Timestamp: 2023-07-03 13:48:47.981629972, Action: BUY, Price: 188.8210831190431, Shares: 20.012486501754996, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.167151
# Step: 15063, Timestamp: 2023-07-03 13:48:48.186813615, Action: BUY, Price: 186.85702519738848, Shares: 10.603301909203699, Symbol: AAPL, Reward: -30468350.466483127, Transaction Cost: 30468350.298158128, Slippage: 0.0, Time Penalty: 0.168325
# Step: 15064, Timestamp: 2023-07-03 13:48:48.186813615, Action: BUY, Price: 190.94154058989764, Shares: 7.18787006631046, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.168325
# Step: 15065, Timestamp: 2023-07-03 13:48:48.186813615, Action: BUY, Price: 186.93371204636608, Shares: 22.962689552297576, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.168325
# Step: 15078, Timestamp: 2023-07-03 13:48:51.812072231, Action: SELL, Price: 196.5014559500396, Shares: 8.573982671179374, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.167205
# Step: 15079, Timestamp: 2023-07-03 13:48:51.812072231, Action: SELL, Price: 196.5098938866325, Shares: 19.726588273857676, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.167205
# Step: 15081, Timestamp: 2023-07-03 13:48:51.812812682, Action: SELL, Price: 191.68609812539353, Shares: 6.6854985614389815, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164514
# Step: 15082, Timestamp: 2023-07-03 13:48:51.812831972, Action: SELL, Price: 192.76578001468133, Shares: 25.367671786796645, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164313
# Step: 15083, Timestamp: 2023-07-03 13:48:51.812849136, Action: SELL, Price: 192.00877747473763, Shares: 10.274190136867814, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.167358
# Step: 15084, Timestamp: 2023-07-03 13:48:51.812849136, Action: SELL, Price: 200.45697373971248, Shares: 14.25376030517335, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.167358
# Step: 15085, Timestamp: 2023-07-03 13:48:51.812849136, Action: SELL, Price: 198.02469005992646, Shares: 7.382862816675446, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.167358
# Step: 15086, Timestamp: 2023-07-03 13:48:51.812849136, Action: SELL, Price: 190.33626658187296, Shares: 20.8717418818402, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.167358
# Step: 15087, Timestamp: 2023-07-03 13:48:51.813628856, Action: SELL, Price: 196.52874471665237, Shares: 20.125612165690665, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164425
# Step: 15088, Timestamp: 2023-07-03 13:48:51.815232564, Action: SELL, Price: 193.23215752439904, Shares: 16.361152468646964, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164968
# Step: 15089, Timestamp: 2023-07-03 13:48:51.815232564, Action: SELL, Price: 192.82949799637723, Shares: 19.412688634027717, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164968
# Step: 15090, Timestamp: 2023-07-03 13:48:52.371768630, Action: SELL, Price: 193.22719155330128, Shares: 18.19556789436309, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.165713
# Step: 15091, Timestamp: 2023-07-03 13:48:52.371768630, Action: SELL, Price: 201.14875019059153, Shares: 16.916655742672553, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.165713
# Step: 15092, Timestamp: 2023-07-03 13:48:52.519642590, Action: SELL, Price: 198.59693698983895, Shares: 9.533762920042715, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164177
# Step: 15096, Timestamp: 2023-07-03 13:48:52.764613280, Action: BUY, Price: 197.89866582342484, Shares: 16.581702510688654, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.164457
# Step: 15097, Timestamp: 2023-07-03 13:48:52.943208837, Action: BUY, Price: 197.86317438926793, Shares: 12.896512950823414, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.164451
# Step: 15098, Timestamp: 2023-07-03 13:48:53.003984060, Action: BUY, Price: 196.84141206599665, Shares: 18.304515064974925, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164399
# Step: 15099, Timestamp: 2023-07-03 13:48:53.011073440, Action: BUY, Price: 194.3718003589886, Shares: 15.7901990955933, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.165145
# Step: 15104, Timestamp: 2023-07-03 13:48:54.970183574, Action: BUY, Price: 208.9290112690908, Shares: 24.095176273986834, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.164971
# Step: 15105, Timestamp: 2023-07-03 13:48:54.970205608, Action: BUY, Price: 193.2826155983926, Shares: 13.659565993047432, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.165179
# Step: 15106, Timestamp: 2023-07-03 13:48:54.970205608, Action: BUY, Price: 189.5511966525304, Shares: 19.88008771096936, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.165179
# Step: 15117, Timestamp: 2023-07-03 13:48:56.407432576, Action: SELL, Price: 191.71127513485845, Shares: 22.15746505188648, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.165661
# Step: 15118, Timestamp: 2023-07-03 13:48:58.801048312, Action: SELL, Price: 195.53195455617785, Shares: 8.74526591187858, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.166034
# Step: 15119, Timestamp: 2023-07-03 13:48:58.801048312, Action: SELL, Price: 189.12540777091917, Shares: 24.15083716334489, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.166034
# Step: 15120, Timestamp: 2023-07-03 13:48:59.354824088, Action: SELL, Price: 198.63527815818097, Shares: 14.867334897349057, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.167014
# Step: 15121, Timestamp: 2023-07-03 13:48:59.401041806, Action: SELL, Price: 198.01219063909835, Shares: 5.940860281652027, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.164287
# Step: 15122, Timestamp: 2023-07-03 13:48:59.546903279, Action: SELL, Price: 185.85655336933652, Shares: 17.473076296445857, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.169858
# Step: 15123, Timestamp: 2023-07-03 13:48:59.546903279, Action: SELL, Price: 191.65955863964615, Shares: 14.256086209154867, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.169858
# Step: 15124, Timestamp: 2023-07-03 13:48:59.546903279, Action: SELL, Price: 187.00655473886664, Shares: 9.644097013103442, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.169858
# Step: 15125, Timestamp: 2023-07-03 13:48:59.546903279, Action: SELL, Price: 191.15152168483073, Shares: 24.23309691350217, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.169858
# Step: 15126, Timestamp: 2023-07-03 13:48:59.546903279, Action: SELL, Price: 199.39362801111847, Shares: 23.787017316415103, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.169858
# Step: 15127, Timestamp: 2023-07-03 13:49:00.084516841, Action: SELL, Price: 191.14759624800087, Shares: 17.151209018277303, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.166996
# Step: 15128, Timestamp: 2023-07-03 13:49:00.084516841, Action: SELL, Price: 190.19339593004216, Shares: 8.278324364219104, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.166996
# Step: 15129, Timestamp: 2023-07-03 13:49:00.084580241, Action: SELL, Price: 195.71560724486008, Shares: 24.799727549249923, Symbol: AAPL, Reward: -32750283.95083303, Transaction Cost: 32750283.77156403, Slippage: 0.009999999999990905, Time Penalty: 0.169269
# Step: 15130, Timestamp: 2023-07-03 13:49:00.084580241, Action: SELL, Price: 195.8800857103085, Shares: 26.49354531383755, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.169269
# Step: 15131, Timestamp: 2023-07-03 13:49:00.084580241, Action: SELL, Price: 198.58226909704544, Shares: 22.863505387960892, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.169269
# Step: 15150, Timestamp: 2023-07-03 13:49:03.422699972, Action: SELL, Price: 185.27806458631073, Shares: 9.47020737623214, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.168114
# Step: 15151, Timestamp: 2023-07-03 13:49:03.422699972, Action: SELL, Price: 184.5114740586019, Shares: 26.49768751916188, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.168114
# Step: 15153, Timestamp: 2023-07-03 13:49:04.674738456, Action: SELL, Price: 187.4814099141893, Shares: 19.30086890425092, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.167154
# Step: 15154, Timestamp: 2023-07-03 13:49:04.674738456, Action: SELL, Price: 192.35945576235892, Shares: 8.106069689628658, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.167154
# Step: 15155, Timestamp: 2023-07-03 13:49:04.674738456, Action: SELL, Price: 201.93934541252733, Shares: 12.667680976782721, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.167154
# Step: 15167, Timestamp: 2023-07-03 13:49:06.830465559, Action: BUY, Price: 187.21947230750365, Shares: 25.30514990284119, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.020000000000010232, Time Penalty: 0.16931
# Step: 15168, Timestamp: 2023-07-03 13:49:06.830465559, Action: BUY, Price: 192.03145237701844, Shares: 16.798851486159236, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.020000000000010232, Time Penalty: 0.16931
# Step: 15169, Timestamp: 2023-07-03 13:49:06.830465559, Action: BUY, Price: 196.7972633000734, Shares: 16.527624841110292, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.020000000000010232, Time Penalty: 0.16931
# Step: 15173, Timestamp: 2023-07-03 13:49:07.455693842, Action: SELL, Price: 183.4512895067181, Shares: 8.646793399869464, Symbol: AAPL, Reward: -90129482.81778459, Transaction Cost: 90129482.64343259, Slippage: 0.009999999999990905, Time Penalty: 0.164352
# Step: 15174, Timestamp: 2023-07-03 13:49:07.455715571, Action: SELL, Price: 199.88427829021333, Shares: 15.54128308952922, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.164781
# Step: 15175, Timestamp: 2023-07-03 13:49:07.531344890, Action: SELL, Price: 184.07401751949416, Shares: 24.452091132971706, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.165376
# Step: 15176, Timestamp: 2023-07-03 13:49:07.531344890, Action: SELL, Price: 200.81153335349623, Shares: 27.812637684023763, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.165376
# Step: 15177, Timestamp: 2023-07-03 13:49:08.558519589, Action: SELL, Price: 187.20182854931386, Shares: 26.17413261805898, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.165917
# Step: 15179, Timestamp: 2023-07-03 13:49:08.558568446, Action: SELL, Price: 192.95674475199547, Shares: 7.720527052238534, Symbol: AAPL, Reward: -95944145.4858977, Transaction Cost: 95944145.3178517, Slippage: 0.0, Time Penalty: 0.168046
# Step: 15180, Timestamp: 2023-07-03 13:49:08.558568446, Action: SELL, Price: 189.7169626230178, Shares: 7.6668564327493, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.168046
# Step: 15181, Timestamp: 2023-07-03 13:49:08.558568446, Action: SELL, Price: 191.85294595984152, Shares: 16.406436331475916, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.168046
# Step: 15182, Timestamp: 2023-07-03 13:49:08.558568446, Action: SELL, Price: 186.6552860085631, Shares: 21.976546805593856, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.168046
# Step: 15183, Timestamp: 2023-07-03 13:49:08.999248354, Action: SELL, Price: 183.997939013501, Shares: 18.776146886228403, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.17042
# Step: 15184, Timestamp: 2023-07-03 13:49:08.999272846, Action: SELL, Price: 193.44095295306852, Shares: 9.731775269682075, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.166646
# Step: 15185, Timestamp: 2023-07-03 13:49:08.999272846, Action: SELL, Price: 191.99278712011164, Shares: 16.416857833394356, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.166646
# Step: 15186, Timestamp: 2023-07-03 13:49:08.999272846, Action: SELL, Price: 183.87240484237893, Shares: 14.745861152760968, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.166646
# Step: 15188, Timestamp: 2023-07-03 13:49:09.061227214, Action: SELL, Price: 197.7518554305867, Shares: 25.30403476538267, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164973
# Step: 15189, Timestamp: 2023-07-03 13:49:09.061227214, Action: SELL, Price: 198.54958217714122, Shares: 17.00650731633524, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164973
# Step: 15190, Timestamp: 2023-07-03 13:49:09.153170864, Action: SELL, Price: 187.3088998446245, Shares: 7.987489041031041, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.166866
# Step: 15191, Timestamp: 2023-07-03 13:49:09.153170864, Action: SELL, Price: 198.63604015400935, Shares: 12.71513146378627, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.166866
# Step: 15192, Timestamp: 2023-07-03 13:49:09.153170864, Action: SELL, Price: 200.66133403443183, Shares: 19.335805983715314, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.166866
# Step: 15193, Timestamp: 2023-07-03 13:49:09.153170864, Action: SELL, Price: 190.28920948291392, Shares: 27.034661873519973, Symbol: AAPL, Reward: -33024440.764267605, Transaction Cost: 33024440.597401604, Slippage: 0.0, Time Penalty: 0.166866
# Step: 15194, Timestamp: 2023-07-03 13:49:09.154870072, Action: SELL, Price: 184.4690431876224, Shares: 25.014121651411788, Symbol: AAPL, Reward: -13747152.382738907, Transaction Cost: 13747152.217984907, Slippage: 0.0, Time Penalty: 0.164754
# Step: 15195, Timestamp: 2023-07-03 13:49:09.155338306, Action: SELL, Price: 186.96677370096663, Shares: 24.877085089549205, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.164859
# Step: 15196, Timestamp: 2023-07-03 13:49:09.155528520, Action: SELL, Price: 189.16773541507342, Shares: 24.589778601564056, Symbol: AAPL, Reward: -13074846.42414348, Transaction Cost: 13074846.24961648, Slippage: 0.009999999999990905, Time Penalty: 0.164527
# Step: 15197, Timestamp: 2023-07-03 13:49:09.155634266, Action: SELL, Price: 199.60004745709912, Shares: 19.553439003323373, Symbol: AAPL, Reward: -33024440.772946604, Transaction Cost: 33024440.597401604, Slippage: 0.009999999999990905, Time Penalty: 0.165545
# Step: 15198, Timestamp: 2023-07-03 13:49:09.185625345, Action: SELL, Price: 196.12829354474505, Shares: 12.550784150341576, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0049999999999954525, Time Penalty: 0.164502
# Step: 15201, Timestamp: 2023-07-03 13:49:10.011197271, Action: SELL, Price: 186.02617343591123, Shares: 6.84819489417939, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.168986
# Step: 15204, Timestamp: 2023-07-03 13:49:10.040172361, Action: SELL, Price: 193.38191820079214, Shares: 6.717916442875353, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.168476
# Step: 15205, Timestamp: 2023-07-03 13:49:10.040172361, Action: SELL, Price: 183.91780876426273, Shares: 17.596557174801543, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.168476
# Step: 15206, Timestamp: 2023-07-03 13:49:10.040172361, Action: SELL, Price: 197.46010163539432, Shares: 17.59301004143795, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.168476
# Step: 15222, Timestamp: 2023-07-03 13:49:16.457799111, Action: SELL, Price: 187.66959598449534, Shares: 26.37150530084584, Symbol: AAPL, Reward: -33024440.775043603, Transaction Cost: 33024440.597401604, Slippage: 0.009999999999990905, Time Penalty: 0.167642
# Step: 15224, Timestamp: 2023-07-03 13:49:18.271352629, Action: SELL, Price: 184.65691097940518, Shares: 24.780451550168888, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164419
# Step: 15225, Timestamp: 2023-07-03 13:49:18.483442249, Action: SELL, Price: 198.33727732104813, Shares: 24.185726700942215, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164822
# Step: 15226, Timestamp: 2023-07-03 13:49:18.483442249, Action: SELL, Price: 194.53991833898053, Shares: 20.208703388099412, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.164822
# Step: 15235, Timestamp: 2023-07-03 13:49:20.593451647, Action: SELL, Price: 192.80737649166892, Shares: 6.454838582542812, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.16435
# Step: 15237, Timestamp: 2023-07-03 13:49:20.859338946, Action: SELL, Price: 200.3464617112977, Shares: 26.938705379219357, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.166125
# Step: 15238, Timestamp: 2023-07-03 13:49:20.859338946, Action: SELL, Price: 196.08562658713356, Shares: 31.939654245448374, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.166125
# Step: 15239, Timestamp: 2023-07-03 13:49:20.859357191, Action: SELL, Price: 189.6956355180658, Shares: 7.184364429623096, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.167453
# Step: 15240, Timestamp: 2023-07-03 13:49:20.859357191, Action: SELL, Price: 198.03211422796443, Shares: 13.74019933407626, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.167453
# Step: 15241, Timestamp: 2023-07-03 13:49:20.859357191, Action: SELL, Price: 193.930451703756, Shares: 31.644742116627583, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.167453
# Step: 15242, Timestamp: 2023-07-03 13:49:21.115718499, Action: SELL, Price: 197.3086355548527, Shares: 10.998089471369413, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.16579
# Step: 15258, Timestamp: 2023-07-03 13:49:27.802872019, Action: SELL, Price: 207.38099275200673, Shares: 31.753374189268943, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164841
# Step: 15259, Timestamp: 2023-07-03 13:49:28.143244914, Action: SELL, Price: 202.22026461910895, Shares: 31.72884417174424, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.171346
# Step: 15260, Timestamp: 2023-07-03 13:49:28.143244914, Action: SELL, Price: 193.0108593663902, Shares: 20.423572207743582, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.171346
# Step: 15261, Timestamp: 2023-07-03 13:49:28.143244914, Action: SELL, Price: 188.77242481845718, Shares: 20.50190642345539, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.171346
# Step: 15267, Timestamp: 2023-07-03 13:49:28.896983772, Action: SELL, Price: 183.98215340939595, Shares: 29.9677502496437, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164473
# Step: 15268, Timestamp: 2023-07-03 13:49:29.004376208, Action: SELL, Price: 186.487634994414, Shares: 26.69928434610302, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.164774
# Step: 15269, Timestamp: 2023-07-03 13:49:29.004457975, Action: SELL, Price: 189.6351626854612, Shares: 32.091993568535024, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.166127
# Step: 15270, Timestamp: 2023-07-03 13:49:29.379495670, Action: SELL, Price: 183.57523612652292, Shares: 19.572889575411676, Symbol: AAPL, Reward: -105264753.74864557, Transaction Cost: 105264753.57269457, Slippage: 0.009999999999990905, Time Penalty: 0.165951
# Step: 15272, Timestamp: 2023-07-03 13:49:29.434129315, Action: BUY, Price: 185.5218765059643, Shares: 12.679927835590208, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.165931
# Step: 15273, Timestamp: 2023-07-03 13:49:29.721304783, Action: BUY, Price: 189.66942408113272, Shares: 22.742861614347134, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164917
# Step: 15274, Timestamp: 2023-07-03 13:49:32.003703175, Action: BUY, Price: 187.54628438323425, Shares: 17.21717589472319, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.165722
# Step: 15291, Timestamp: 2023-07-03 13:49:35.666450130, Action: BUY, Price: 187.21004999934985, Shares: 31.576476224176524, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.167731
# Step: 15293, Timestamp: 2023-07-03 13:49:35.666450130, Action: BUY, Price: 201.69359389452205, Shares: 28.340535059406093, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.167731
# Step: 15294, Timestamp: 2023-07-03 13:49:35.666450130, Action: BUY, Price: 189.02719866880923, Shares: 20.987124075030287, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.167731
# Step: 15295, Timestamp: 2023-07-03 13:49:35.667275311, Action: BUY, Price: 191.3133340205297, Shares: 17.26303558773683, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.164238
# Step: 15296, Timestamp: 2023-07-03 13:49:35.920701995, Action: BUY, Price: 197.00377018322055, Shares: 18.114240445154508, Symbol: AAPL, Reward: -33024440.762386605, Transaction Cost: 33024440.597401604, Slippage: 0.0, Time Penalty: 0.164985
# Step: 15297, Timestamp: 2023-07-03 13:49:35.920701995, Action: BUY, Price: 185.92679274676922, Shares: 8.175306100308035, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164985
# Step: 15298, Timestamp: 2023-07-03 13:49:35.920746583, Action: BUY, Price: 189.95426232426644, Shares: 18.84946600729355, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.165358
# Step: 15299, Timestamp: 2023-07-03 13:49:36.004897473, Action: BUY, Price: 189.98903294119313, Shares: 24.379822228632285, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.16445
# Step: 15305, Timestamp: 2023-07-03 13:49:38.254324057, Action: SELL, Price: 186.5723340977475, Shares: 26.951640839777678, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.166224
# Step: 15306, Timestamp: 2023-07-03 13:49:38.254324057, Action: SELL, Price: 184.63267804564146, Shares: 26.2677743259146, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.166224
# Step: 15307, Timestamp: 2023-07-03 13:49:40.621930131, Action: SELL, Price: 201.1651875736105, Shares: 28.14811461058562, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.170653
# Step: 15308, Timestamp: 2023-07-03 13:49:40.621930131, Action: SELL, Price: 184.46911132764006, Shares: 14.765025494779772, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.170653
# Step: 15309, Timestamp: 2023-07-03 13:49:40.621930131, Action: SELL, Price: 186.85767190930204, Shares: 20.686013226667356, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.170653
# Step: 15310, Timestamp: 2023-07-03 13:49:40.621930131, Action: SELL, Price: 202.47527090671892, Shares: 23.137500039455745, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.170653
# Step: 15311, Timestamp: 2023-07-03 13:49:40.621930131, Action: SELL, Price: 199.34206613908563, Shares: 13.512937322856972, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.170653
# Step: 15312, Timestamp: 2023-07-03 13:49:40.634109127, Action: SELL, Price: 186.31136651190812, Shares: 10.370007422459402, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.168158
# Step: 15313, Timestamp: 2023-07-03 13:49:40.634109127, Action: SELL, Price: 196.12146177769003, Shares: 9.80306723711381, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.168158
# Step: 15314, Timestamp: 2023-07-03 13:49:40.634109127, Action: SELL, Price: 188.6654445985909, Shares: 22.08605039380366, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.168158
# Step: 15315, Timestamp: 2023-07-03 13:49:40.783188557, Action: SELL, Price: 198.2774219669267, Shares: 20.049476868500733, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.165265
# Step: 15316, Timestamp: 2023-07-03 13:49:40.885098021, Action: SELL, Price: 185.30737571559746, Shares: 14.71548602834067, Symbol: AAPL, Reward: -38565926.18627132, Transaction Cost: 38565926.01176232, Slippage: 0.009999999999990905, Time Penalty: 0.164509
# Step: 15317, Timestamp: 2023-07-03 13:49:43.003802354, Action: SELL, Price: 199.96386685290372, Shares: 21.42529997763218, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.165144
# Step: 15318, Timestamp: 2023-07-03 13:49:43.070789733, Action: SELL, Price: 185.62180896300057, Shares: 21.68253952105899, Symbol: AAPL, Reward: -54955443.668731965, Transaction Cost: 54955443.49451096, Slippage: 0.009999999999990905, Time Penalty: 0.164221
# Step: 15319, Timestamp: 2023-07-03 13:49:43.070804005, Action: SELL, Price: 193.01473881691516, Shares: 14.591955815736886, Symbol: AAPL, Reward: -39261029.42862317, Transaction Cost: 39261029.25427117, Slippage: 0.009999999999990905, Time Penalty: 0.164352
# Step: 15320, Timestamp: 2023-07-03 13:49:43.070811146, Action: SELL, Price: 195.56460568533896, Shares: 17.831830634609926, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.164624
# Step: 15321, Timestamp: 2023-07-03 13:49:43.189892200, Action: SELL, Price: 194.75354828834574, Shares: 22.199595883408097, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0049999999999954525, Time Penalty: 0.166055
# Step: 15322, Timestamp: 2023-07-03 13:49:43.189918082, Action: SELL, Price: 202.57186250170616, Shares: 25.39705860841447, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0049999999999954525, Time Penalty: 0.165607
# Step: 15323, Timestamp: 2023-07-03 13:49:45.421315066, Action: SELL, Price: 189.8735473058833, Shares: 14.007940693991891, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.171661
# Step: 15324, Timestamp: 2023-07-03 13:49:45.421315066, Action: SELL, Price: 190.0499101075674, Shares: 28.942824456802413, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.171661
# Step: 15325, Timestamp: 2023-07-03 13:49:45.421315066, Action: SELL, Price: 184.28516883340188, Shares: 8.573457998774384, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.171661
# Step: 15326, Timestamp: 2023-07-03 13:49:46.003738832, Action: SELL, Price: 186.10542001603022, Shares: 18.598282787818608, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.166618
# Step: 15327, Timestamp: 2023-07-03 13:49:46.003738832, Action: SELL, Price: 187.34924350798897, Shares: 21.81019750965943, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.166618
# Step: 15328, Timestamp: 2023-07-03 13:49:46.354578551, Action: SELL, Price: 196.75960596155596, Shares: 15.17481113895529, Symbol: AAPL, Reward: -41494027.631870866, Transaction Cost: 41494027.45743187, Slippage: 0.009999999999990905, Time Penalty: 0.164439
# Step: 15331, Timestamp: 2023-07-03 13:49:46.354683946, Action: BUY, Price: 195.6479653862068, Shares: 14.191428033288725, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.164372
# Step: 15332, Timestamp: 2023-07-03 13:49:46.354713034, Action: BUY, Price: 184.81281278929748, Shares: 16.942722012352235, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.168218
# Step: 15333, Timestamp: 2023-07-03 13:49:46.354713034, Action: BUY, Price: 186.111319568743, Shares: 21.93271693451131, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.168218
# Step: 15334, Timestamp: 2023-07-03 13:49:46.355246089, Action: BUY, Price: 195.1459356746295, Shares: 25.6908634324809, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.165194
# Step: 15337, Timestamp: 2023-07-03 13:49:48.198045196, Action: BUY, Price: 195.1680663216098, Shares: 15.387708712699474, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.165699
# Step: 15338, Timestamp: 2023-07-03 13:49:48.198045196, Action: BUY, Price: 184.9632442337057, Shares: 22.713883657953282, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.165699
# Step: 15339, Timestamp: 2023-07-03 13:49:48.198141894, Action: BUY, Price: 199.4494501400188, Shares: 7.185105795277356, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.165222
# Step: 15340, Timestamp: 2023-07-03 13:49:49.004881297, Action: BUY, Price: 198.7812297410836, Shares: 30.176722736363395, Symbol: AAPL, Reward: -33024440.762033604, Transaction Cost: 33024440.597401604, Slippage: 0.0, Time Penalty: 0.164632
# Step: 15341, Timestamp: 2023-07-03 13:49:49.004964536, Action: BUY, Price: 184.64077658746285, Shares: 19.64493582393839, Symbol: AAPL, Reward: -33024440.761560604, Transaction Cost: 33024440.597401604, Slippage: 0.0, Time Penalty: 0.164159
# Step: 15342, Timestamp: 2023-07-03 13:49:49.004985437, Action: BUY, Price: 199.95090478915495, Shares: 9.634137594916742, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.164876
# Step: 15343, Timestamp: 2023-07-03 13:49:49.004995723, Action: BUY, Price: 195.16040483279087, Shares: 17.20148879463287, Symbol: AAPL, Reward: -33024440.772603605, Transaction Cost: 33024440.597401604, Slippage: 0.009999999999990905, Time Penalty: 0.165202
# Step: 15344, Timestamp: 2023-07-03 13:49:49.005326304, Action: BUY, Price: 190.0714071384299, Shares: 32.105282422095854, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164217
# Step: 15345, Timestamp: 2023-07-03 13:49:49.005352427, Action: BUY, Price: 200.3385871540911, Shares: 25.54184247541688, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.16899
# Step: 15346, Timestamp: 2023-07-03 13:49:49.005352427, Action: BUY, Price: 186.59214249894785, Shares: 32.666128636658236, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.16899
# ...
# Step: 58827, Timestamp: 2023-07-03 17:08:48.593015226, Action: BUY, Price: 190.7926554059854, Shares: 0.35138040000006676, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.01999999999998181, Time Penalty: 0.167801
# Step: 58828, Timestamp: 2023-07-03 17:08:48.593015226, Action: BUY, Price: 201.70235828815672, Shares: 0.08303586096098871, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.01999999999998181, Time Penalty: 0.167801
# Step: 58829, Timestamp: 2023-07-03 17:08:48.614150379, Action: BUY, Price: 186.86462849550207, Shares: 0.22541259736615324, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.030000000000001137, Time Penalty: 0.16591
# Step: 58830, Timestamp: 2023-07-03 17:08:48.614150379, Action: BUY, Price: 199.6954729965916, Shares: 0.21887058764244238, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.030000000000001137, Time Penalty: 0.16591
# Step: 58831, Timestamp: 2023-07-03 17:08:56.814994096, Action: BUY, Price: 202.02113753856779, Shares: 0.10981259798760448, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164458
# Step: 58832, Timestamp: 2023-07-03 17:09:02.502244837, Action: BUY, Price: 183.40395386718765, Shares: 0.18783535902460421, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164544
# Step: 58833, Timestamp: 2023-07-03 17:09:07.068876738, Action: BUY, Price: 193.22942601849763, Shares: 0.09091675748409953, Symbol: AAPL, Reward: -12366042.97547005, Transaction Cost: 12366042.81076905, Slippage: 0.0, Time Penalty: 0.164701
# Step: 58834, Timestamp: 2023-07-03 17:09:09.097388683, Action: BUY, Price: 183.50234925097416, Shares: 0.13012231221915435, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.165507
# Step: 58835, Timestamp: 2023-07-03 17:09:21.764806562, Action: BUY, Price: 190.2557716906303, Shares: 0.16751362138132656, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.01999999999998181, Time Penalty: 0.165555
# Step: 58836, Timestamp: 2023-07-03 17:09:21.764806562, Action: BUY, Price: 193.49119311308428, Shares: 0.19501798485851166, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.01999999999998181, Time Penalty: 0.165555
# Step: 58837, Timestamp: 2023-07-03 17:09:38.336284767, Action: BUY, Price: 193.96282476737724, Shares: 0.08628411638741486, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.009999999999990905, Time Penalty: 0.164991
# Step: 58842, Timestamp: 2023-07-03 17:11:24.706537194, Action: BUY, Price: 188.47535618925892, Shares: 0.08897312874914141, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.165942
# Step: 58857, Timestamp: 2023-07-03 17:15:10.922011028, Action: BUY, Price: 194.22953087264486, Shares: 0.33186035297432137, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.12999999999999545, Time Penalty: 0.166801
# Step: 58858, Timestamp: 2023-07-03 17:15:10.922011028, Action: BUY, Price: 194.5522837738691, Shares: 0.22748435237975706, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.21000000000000796, Time Penalty: 0.166801
# Step: 58859, Timestamp: 2023-07-03 17:15:10.922011028, Action: BUY, Price: 196.26291171188907, Shares: 0.32418350790918665, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.21999999999999886, Time Penalty: 0.166801
# Step: 58860, Timestamp: 2023-07-03 17:15:14.476702470, Action: BUY, Price: 192.69146668659465, Shares: 0.09544281213573648, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.21000000000000796, Time Penalty: 0.16582
# Step: 58872, Timestamp: 2023-07-03 17:16:59.560316579, Action: SELL, Price: 187.26332012197003, Shares: 0.18720691640502618, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.16468
# Step: 58873, Timestamp: 2023-07-03 17:16:59.560340821, Action: SELL, Price: 187.0133941880847, Shares: 0.19827228482593715, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164399
# Step: 58874, Timestamp: 2023-07-03 17:17:22.204259243, Action: SELL, Price: 185.87264856433433, Shares: 0.12017359010493128, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.165343
# Step: 58899, Timestamp: 2023-07-03 17:30:09.628158781, Action: BUY, Price: 189.1395638678054, Shares: 0.11431200237779564, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.05000000000001137, Time Penalty: 0.16515
# Step: 58900, Timestamp: 2023-07-03 17:30:22.771174114, Action: BUY, Price: 192.91571858378055, Shares: 0.3114576766677311, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.09999999999999432, Time Penalty: 0.167612
# Step: 58901, Timestamp: 2023-07-03 17:30:22.771174114, Action: BUY, Price: 191.34650528429069, Shares: 0.23480226478052357, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.09999999999999432, Time Penalty: 0.167612
# Step: 58902, Timestamp: 2023-07-03 17:30:22.771174114, Action: BUY, Price: 190.4114930191328, Shares: 0.19140073994101353, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.09999999999999432, Time Penalty: 0.167612
# Step: 58903, Timestamp: 2023-07-03 17:32:04.682308037, Action: BUY, Price: 188.56197136076506, Shares: 0.36007653201015444, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.12000000000000455, Time Penalty: 0.164844
# Step: 58914, Timestamp: 2023-07-03 17:43:40.101647940, Action: SELL, Price: 184.57337256303398, Shares: 0.09122523923488089, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164366
# Step: 58915, Timestamp: 2023-07-03 17:43:49.987887262, Action: SELL, Price: 200.0627155151077, Shares: 0.165411670816283, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.165937
# Step: 58916, Timestamp: 2023-07-03 17:45:54.491455614, Action: SELL, Price: 201.51179467176834, Shares: 0.36062966568727867, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164654
# Step: 58917, Timestamp: 2023-07-03 17:46:12.432219556, Action: SELL, Price: 201.97293405085307, Shares: 0.16148505613055983, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164465
# Step: 58930, Timestamp: 2023-07-03 17:50:43.078869951, Action: BUY, Price: 190.3979127610879, Shares: 0.10776045003107519, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164475
# Step: 58931, Timestamp: 2023-07-03 17:50:45.336054019, Action: BUY, Price: 183.85779297584884, Shares: 0.23033489970307952, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164333
# Step: 58932, Timestamp: 2023-07-03 17:52:03.870333943, Action: BUY, Price: 187.18546642006805, Shares: 0.159960418051699, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.020000000000010232, Time Penalty: 0.165145
# Step: 58933, Timestamp: 2023-07-03 17:52:28.447424983, Action: BUY, Price: 191.1544713677469, Shares: 0.27704237479031335, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.060000000000002274, Time Penalty: 0.164698
# Step: 58955, Timestamp: 2023-07-03 18:11:52.297300608, Action: SELL, Price: 194.29625732210633, Shares: 0.08179111868188998, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164581
# Step: 58978, Timestamp: 2023-07-03 18:28:45.693217583, Action: BUY, Price: 184.69417307871325, Shares: 0.3365295132303139, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.166149
# Step: 58979, Timestamp: 2023-07-03 18:28:45.693217583, Action: BUY, Price: 193.00113948549563, Shares: 0.15991190127283722, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.030000000000001137, Time Penalty: 0.166149
# Step: 58984, Timestamp: 2023-07-03 18:29:23.476430905, Action: BUY, Price: 193.33310236439868, Shares: 0.2649525751116474, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.030000000000001137, Time Penalty: 0.164713
# Step: 58985, Timestamp: 2023-07-03 18:29:24.173178425, Action: SELL, Price: 185.02877591380272, Shares: 0.08428697675634995, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164963
# Step: 58986, Timestamp: 2023-07-03 18:29:51.832641726, Action: SELL, Price: 194.72869229022004, Shares: 0.29385211811876394, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164607
# Step: 59014, Timestamp: 2023-07-03 18:46:49.519613842, Action: BUY, Price: 185.58141722997834, Shares: 0.3087886901380029, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.16473
# Step: 59015, Timestamp: 2023-07-03 18:47:12.034975475, Action: BUY, Price: 184.62830624881425, Shares: 0.3112235346521359, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.165238
# Step: 59021, Timestamp: 2023-07-03 18:48:19.772706650, Action: SELL, Price: 187.51527493278184, Shares: 0.2991789158019487, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.165374
# Step: 59022, Timestamp: 2023-07-03 18:48:19.773284488, Action: SELL, Price: 197.4192157699898, Shares: 0.3371738864350922, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164663
# Step: 59023, Timestamp: 2023-07-03 18:48:23.864621336, Action: SELL, Price: 183.73491723061838, Shares: 0.24223050851473582, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164933
# Step: 59024, Timestamp: 2023-07-03 18:49:25.155568364, Action: BUY, Price: 199.64451320883614, Shares: 0.1510084251923009, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.040000000000020464, Time Penalty: 0.164182
# Step: 59031, Timestamp: 2023-07-03 18:54:59.172352910, Action: BUY, Price: 192.4220370929544, Shares: 0.2918904939797055, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.05000000000001137, Time Penalty: 0.166274
# Step: 59062, Timestamp: 2023-07-03 19:14:35.728887866, Action: BUY, Price: 182.99610274138993, Shares: 0.3030746109385355, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.020000000000010232, Time Penalty: 0.164427
# Step: 59063, Timestamp: 2023-07-03 19:14:54.080645299, Action: BUY, Price: 182.80599279188303, Shares: 0.330127642801585, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.020000000000010232, Time Penalty: 0.16473
# Step: 59064, Timestamp: 2023-07-03 19:15:18.574846552, Action: BUY, Price: 186.9447704909729, Shares: 0.3438011324397101, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164666
# Step: 59080, Timestamp: 2023-07-03 19:18:12.639452306, Action: SELL, Price: 185.67126658533644, Shares: 0.09147439463379121, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164652
# Step: 59111, Timestamp: 2023-07-03 19:38:13.756616379, Action: SELL, Price: 186.39967059083378, Shares: 0.2978516966630857, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.167734
# Step: 59112, Timestamp: 2023-07-03 19:38:13.757441491, Action: SELL, Price: 185.61925706732973, Shares: 0.28112079895652015, Symbol: AAPL, Reward: -9940887.743333131, Transaction Cost: 9940887.577966131, Slippage: 0.0, Time Penalty: 0.165367
# Step: 59113, Timestamp: 2023-07-03 19:38:43.528592158, Action: SELL, Price: 187.06977826276113, Shares: 0.3019709738367306, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.09000000000000341, Time Penalty: 0.165066
# Step: 59114, Timestamp: 2023-07-03 19:38:50.501542123, Action: SELL, Price: 192.75408567591037, Shares: 0.3422325291438815, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.05000000000001137, Time Penalty: 0.164648
# Step: 59115, Timestamp: 2023-07-03 19:39:01.516113870, Action: SELL, Price: 195.69160055955686, Shares: 0.08184103993519985, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.05000000000001137, Time Penalty: 0.165397
# Step: 59116, Timestamp: 2023-07-03 19:39:30.394642738, Action: SELL, Price: 197.35754674609723, Shares: 0.14874639083850863, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.05000000000001137, Time Penalty: 0.164521
# Step: 59117, Timestamp: 2023-07-03 19:39:34.251031363, Action: SELL, Price: 186.34169499630266, Shares: 0.1688650064212874, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.030000000000001137, Time Penalty: 0.165078
# Step: 59126, Timestamp: 2023-07-03 19:50:10.425204413, Action: BUY, Price: 199.2633691709451, Shares: 0.31367132139521625, Symbol: AAPL, Reward: -42140860.228701286, Transaction Cost: 42140860.024424285, Slippage: 0.03999999999999204, Time Penalty: 0.164277
# Step: 59129, Timestamp: 2023-07-03 19:50:47.946187986, Action: BUY, Price: 198.0951067243757, Shares: 0.16269657816576308, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.04999999999998295, Time Penalty: 0.165068
# Step: 59155, Timestamp: 2023-07-03 20:02:45.115763195, Action: BUY, Price: 193.0291952380827, Shares: 0.20280102208816064, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.01999999999998181, Time Penalty: 0.164945
# Step: 59178, Timestamp: 2023-07-03 20:06:32.624310992, Action: SELL, Price: 191.51704025091817, Shares: 0.0770732525743566, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.165051
# Step: 59179, Timestamp: 2023-07-03 20:06:37.972363577, Action: SELL, Price: 188.57148006623888, Shares: 0.25008221759611854, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.165373
# Step: 59180, Timestamp: 2023-07-03 20:06:51.262073950, Action: SELL, Price: 193.10569128024025, Shares: 0.22398371583438387, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.164555
# Step: 59181, Timestamp: 2023-07-03 20:06:51.389569795, Action: SELL, Price: 186.42258938618102, Shares: 0.1915314707717041, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.010000000000019327, Time Penalty: 0.165098
# Step: 59185, Timestamp: 2023-07-03 20:07:34.688195747, Action: SELL, Price: 201.2031724428888, Shares: 0.14794324912066173, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.165314
# Step: 59186, Timestamp: 2023-07-03 20:07:52.971048774, Action: SELL, Price: 190.6792884350244, Shares: 0.16461134634112198, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164549
# Step: 59187, Timestamp: 2023-07-03 20:07:53.744169638, Action: SELL, Price: 183.40542559970126, Shares: 0.12633499689289956, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.16485
# Step: 59188, Timestamp: 2023-07-03 20:08:27.455354760, Action: SELL, Price: 197.39486640324768, Shares: 0.19869570001816408, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.16489
# Step: 59189, Timestamp: 2023-07-03 20:08:44.349634108, Action: SELL, Price: 190.56667899974926, Shares: 0.33736858916927215, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.165237
# Step: 59217, Timestamp: 2023-07-03 20:48:11.839440549, Action: SELL, Price: 197.80689413641926, Shares: 0.07840036488851126, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.165027
# Step: 59225, Timestamp: 2023-07-03 20:57:03.190402086, Action: SELL, Price: 197.56173980473648, Shares: 0.34564867955644524, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164705
# Step: 59226, Timestamp: 2023-07-03 20:57:24.173998107, Action: SELL, Price: 192.7802633664851, Shares: 0.30639149114160025, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164371
# Step: 59227, Timestamp: 2023-07-03 20:57:40.644830740, Action: SELL, Price: 190.5627502332692, Shares: 0.3017422530670983, Symbol: AAPL, Reward: nan, Transaction Cost: nan, Slippage: 0.0, Time Penalty: 0.164885

# %%
df=market_features_df.copy()

# %%
df['timestamp']=pd.to_datetime(df['ts_recv'])

# %%
df.head()
# Out:
#                 ts_recv             ts_event  rtype  publisher_id  \
# 35  1688371212400103305  1688371212399937688      1             2
# 36  1688371214386057385  1688371214385893078      1             2
# 37  1688371214386063777  1688371214385899379      1             2
# 38  1688371215804852019  1688371215804687301      1             2
# 39  1688371216978631317  1688371216978466819      1             2
#
#     instrument_id action side  depth   price  size  flags  ts_in_delta  \
# 35             32      T    B      0  194.05    56    130       165617
# 36             32      T    N      0  194.05    50    130       164307
# 37             32      T    N      0  194.05    50    130       164398
# 38             32      T    B      0  194.21    10    130       164718
# 39            470      T    A      0  114.57    43    130       164498
#
#     sequence  bid_px_00  ask_px_00  bid_sz_00  ask_sz_00  bid_ct_00  \
# 35    324353     194.00     194.05       3079         56          2
# 36    326232     194.00     194.30       3101         19          4
# 37    326233     194.00     194.30       3101         19          4
# 38    328131     194.00     194.21       3101         29          4
# 39    329439     114.57     114.76         43         27          1
#
#     ask_ct_00 symbol   Close  Volume    High     Low    Open        RSI  \
# 35          1   AAPL  194.05      56  194.05  194.00  194.05  51.852848
# 36         10   AAPL  194.05      50  194.30  194.00  194.05  51.852848
# 37         10   AAPL  194.05      50  194.30  194.00  194.05  51.852848
# 38          1   AAPL  194.21      10  194.21  194.00  194.05  51.895447
# 39          1    AMD  114.57      43  114.76  114.57  194.21  35.201020
#
#         MACD  MACD_signal  MACD_hist    Stoch_k    Stoch_d    OBV    Upper_BB  \
# 35 -2.561087    -3.619556   1.058469  99.974582  99.974582 -282.0  254.713931
# 36 -1.532555    -3.202156   1.669601  99.930172  99.959779 -282.0  254.718308
# 37 -0.709260    -2.703577   1.994317  99.885761  99.930172 -282.0  254.721956
# 38 -0.043381    -2.171538   2.128156  99.875196  99.897043 -272.0  254.737322
# 39 -5.874236    -2.912077  -2.962159  83.062571  94.274509 -315.0  257.373490
#
#     Middle_BB    Lower_BB  ATR_1      ATR_2      ATR_5     ATR_10     ATR_20  \
# 35   186.1505  117.587069   0.05   7.422578  23.240495  19.656509  12.550193
# 36   186.1535  117.588692   0.30   3.861289  18.652396  17.720858  11.937684
# 37   186.1560  117.590044   0.30   2.080645  14.981917  15.978772  11.355800
# 38   186.1665  117.595678   0.21   1.145322  12.027533  14.401895  10.798510
# 39   182.1950  107.016510  79.64  40.392661  25.550027  20.925705  14.240584
#
#           ADX        +DI        -DI         CCI       DLR        TWAP  \
# 35  69.565924  51.717387  47.989962    0.000000  0.000000  189.649722
# 36  64.872152  51.762467  47.921535  166.666667  0.000000  189.768649
# 37  60.513649  51.683105  47.848062   83.333333  0.000000  189.881316
# 38  56.466467  51.623439  47.792823   79.268293  0.000824  189.992308
# 39  54.540006  35.082367  64.436445 -166.666667 -0.527754  188.106750
#
#           VWAP                     timestamp
# 35  192.248240 2023-07-03 08:00:12.400103305
# 36  192.297868 2023-07-03 08:00:14.386057385
# 37  192.344972 2023-07-03 08:00:14.386063777
# 38  192.353879 2023-07-03 08:00:15.804852019
# 39  190.699287 2023-07-03 08:00:16.978631317
